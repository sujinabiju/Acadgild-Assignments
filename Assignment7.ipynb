# %%
import numpy as np
import pandas as pd
import sqlite3 as db
from pandasql import sqldf

# %%
names=['Age','Workclass','Fnlwt','Education','Education-num','Marital-status','Occupation','Relationship','Race','Sex','Capital-gain','Capital-loss','hours-per-week','Native-country','Income']
sqladb=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',names=names,sep=r'\s*,\s*',engine='python',na_values="?")
#sqladb.drop('results',axis=1,inplace=True)

# %%
conn=db.connect('affair.db')

# %%
sqladb.to_sql('mytable',conn)

# %%
sql_string="SELECT * FROM mytable LIMIT 10"

# %%
pd.read_sql(sql_string,conn)
# Out:
#    index  Age         Workclass   Fnlwt  Education  Education-num  \
# 0      0   39         State-gov   77516  Bachelors             13
# 1      1   50  Self-emp-not-inc   83311  Bachelors             13
# 2      2   38           Private  215646    HS-grad              9
# 3      3   53           Private  234721       11th              7
# 4      4   28           Private  338409  Bachelors             13
# 5      5   37           Private  284582    Masters             14
# 6      6   49           Private  160187        9th              5
# 7      7   52  Self-emp-not-inc  209642    HS-grad              9
# 8      8   31           Private   45781    Masters             14
# 9      9   42           Private  159449  Bachelors             13
#
#           Marital-status         Occupation   Relationship   Race     Sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
sql_string="SELECT AVG([hours-per-week]) as Average FROM mytable WHERE Workclass='Private'"

# %%
pd.read_sql(sql_string,conn)
# Out:
#      Average
# 0  40.267096

# %%
sql_string="SELECT DISTINCT(Education),COUNT(Education) as frequency FROM mytable GROUP BY Education"

# %%
pd.read_sql(sql_string,conn)
# Out:
#        Education  frequency
# 0           10th        933
# 1           11th       1175
# 2           12th        433
# 3        1st-4th        168
# 4        5th-6th        333
# 5        7th-8th        646
# 6            9th        514
# 7     Assoc-acdm       1067
# 8      Assoc-voc       1382
# 9      Bachelors       5355
# 10     Doctorate        413
# 11       HS-grad      10501
# 12       Masters       1723
# 13     Preschool         51
# 14   Prof-school        576
# 15  Some-college       7291

# %%
sql_string="SELECT DISTINCT(Occupation),COUNT(Occupation) as frequency FROM mytable GROUP BY Occupation"

# %%
pd.read_sql(sql_string,conn)
# Out:
#            Occupation  frequency
# 0                None          0
# 1        Adm-clerical       3770
# 2        Armed-Forces          9
# 3        Craft-repair       4099
# 4     Exec-managerial       4066
# 5     Farming-fishing        994
# 6   Handlers-cleaners       1370
# 7   Machine-op-inspct       2002
# 8       Other-service       3295
# 9     Priv-house-serv        149
# 10     Prof-specialty       4140
# 11    Protective-serv        649
# 12              Sales       3650
# 13       Tech-support        928
# 14   Transport-moving       1597

# %%
sql_string="SELECT DISTINCT(Relationship),COUNT(Relationship) as frequency FROM mytable GROUP BY Relationship"

# %%
pd.read_sql(sql_string,conn)
# Out:
#      Relationship  frequency
# 0         Husband      13193
# 1   Not-in-family       8305
# 2  Other-relative        981
# 3       Own-child       5068
# 4       Unmarried       3446
# 5            Wife       1568

# %%
sql_string="SELECT * FROM mytable WHERE Education='Masters' AND Workclass='Private' AND [Marital-status]='Married-civ-spouse' "

# %%
pd.read_sql(sql_string,conn)
# Out:
#      index  Age Workclass   Fnlwt Education  Education-num  \
# 0        5   37   Private  284582   Masters             14
# 1       87   33   Private  202051   Masters             14
# 2      100   76   Private  124191   Masters             14
# 3      188   31   Private   99928   Masters             14
# 4      198   35   Private  138992   Masters             14
# 5      311   34   Private  142897   Masters             14
# 6      361   62   Private  270092   Masters             14
# 7      405   41   Private  445382   Masters             14
# 8      435   33   Private  208405   Masters             14
# 9      468   49   Private  192776   Masters             14
# 10     606   51   Private  410114   Masters             14
# 11     697   31   Private  118710   Masters             14
# 12     777   34   Private   73585   Masters             14
# 13     895   40   Private  170108   Masters             14
# 14     916   43   Private  158926   Masters             14
# ...

# %%
sql_string="SELECT Workclass,AVG(Age) as avg,MIN(Age) as min,MAX(Age) as max from mytable GROUP BY Workclass"

# %%
pd.read_sql(sql_string,conn)
# Out:
#           Workclass        avg  min  max
# 0              None  40.960240   17   90
# 1       Federal-gov  42.590625   17   90
# 2         Local-gov  41.751075   17   90
# 3      Never-worked  20.571429   17   30
# 4           Private  36.797585   17   90
# 5      Self-emp-inc  46.017025   17   84
# 6  Self-emp-not-inc  44.969697   17   90
# 7         State-gov  39.436055   17   81
# 8       Without-pay  47.785714   19   72

# %%
sql_string="SELECT [Native-country], Age,COUNT(Age) as freq FROM mytable GROUP BY [Native-country]"

# %%
pd.read_sql(sql_string,conn)
# Out:
#                 Native-country  Age   freq
# 0                         None   81    583
# 1                     Cambodia   48     19
# 2                       Canada   32    121
# 3                        China   23     75
# 4                     Columbia   49     59
# 5                         Cuba   48     95
# 6           Dominican-Republic   45     70
# 7                      Ecuador   27     28
# 8                  El-Salvador   39    106
# 9                      England   48     90
# 10                      France   64     29
# 11                     Germany   74    137
# 12                      Greece   23     29
# 13                   Guatemala   22     64
# 14                       Haiti   29     44
# 15          Holand-Netherlands   32      1
# 16                    Honduras   30     13
# 17                        Hong   28     20
# 18                     Hungary   47     13
# 19                       India   23    100
# 20                        Iran   42     43
# ...

# %%
sql_string="SELECT *,([Capital-gain]+[Capital-loss]) as [Net-Capital-Gain] from mytable"

# %%
pd.read_sql(sql_string,conn)
# Out:
#        index  Age         Workclass   Fnlwt     Education  Education-num  \
# 0          0   39         State-gov   77516     Bachelors             13
# 1          1   50  Self-emp-not-inc   83311     Bachelors             13
# 2          2   38           Private  215646       HS-grad              9
# 3          3   53           Private  234721          11th              7
# 4          4   28           Private  338409     Bachelors             13
# 5          5   37           Private  284582       Masters             14
# 6          6   49           Private  160187           9th              5
# 7          7   52  Self-emp-not-inc  209642       HS-grad              9
# 8          8   31           Private   45781       Masters             14
# 9          9   42           Private  159449     Bachelors             13
# 10        10   37           Private  280464  Some-college             10
# 11        11   30         State-gov  141297     Bachelors             13
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:', echo=True)

# %%
from sqlalchemy.ext.declarative import declarative_base

# %%
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String

# %%
class User(Base):
    __tablename__ = 'alchemy'
    id = Column(Integer, primary_key=True)
    age = Column(Integer)
    workclass = Column(String) 
    fnlwt = Column(Integer)
    education=Column(String)
    educationnum=Column(Integer)
    maritalstatus=Column(String)
    occupation=Column(String)
    relationship=Column(String)
    sex=Column(String)
    race=Column(String)
    capitalgain=Column(Integer)
    capitalloss=Column(Integer)
    hoursperweek=Column(Integer)
    nativecountry=Column(String)
    income=Column(String)

# %%
User.__table__
# Out:
# Table('alchemy', MetaData(bind=None), Column('id', Integer(), table=<alchemy>, primary_key=True, nullable=False), Column('age', Integer(), table=<alchemy>), Column('workclass', String(), table=<alchemy>), Column('fnlwt', Integer(), table=<alchemy>), Column('education', String(), table=<alchemy>), Column('educationnum', Integer(), table=<alchemy>), Column('maritalstatus', String(), table=<alchemy>), Column('occupation', String(), table=<alchemy>), Column('relationship', String(), table=<alchemy>), Column('sex', String(), table=<alchemy>), Column('race', String(), table=<alchemy>), Column('capitalgain', Integer(), table=<alchemy>), Column('capitalloss', Integer(), table=<alchemy>), Column('hoursperweek', Integer(), table=<alchemy>), Column('nativecountry', String(), table=<alchemy>), Column('income', String(), table=<alchemy>), schema=None)

# %%
Base.metadata.create_all(engine)
# Out:
# 2018-09-15 09:04:00,617 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-09-15 09:04:00,631 INFO sqlalchemy.engine.base.Engine ()
# 2018-09-15 09:04:00,634 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-09-15 09:04:00,635 INFO sqlalchemy.engine.base.Engine ()
# 2018-09-15 09:04:00,637 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("alchemy")
# 2018-09-15 09:04:00,638 INFO sqlalchemy.engine.base.Engine ()
# 2018-09-15 09:04:00,642 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE alchemy (
# 	id INTEGER NOT NULL,
# 	age INTEGER,
# 	workclass VARCHAR,
# 	fnlwt INTEGER,
# 	education VARCHAR,
# 	educationnum INTEGER,
# 	maritalstatus VARCHAR,
# 	occupation VARCHAR,
# 	relationship VARCHAR,
# 	sex VARCHAR,
# 	race VARCHAR,
# 	capitalgain INTEGER,
# 	capitalloss INTEGER,
# 	hoursperweek INTEGER,
# 	nativecountry VARCHAR,
# 	income VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# ...

# %%
from sqlalchemy.orm import sessionmaker

# %%
Session = sessionmaker(bind=engine)

# %%
Session = sessionmaker()

# %%
Session.configure(bind=engine)

# %%
session = Session()

# %%
our_user
